# %% [markdown]
# <a href="https://colab.research.google.com/github/yashyadvv/ACMBMU_Hacktoberfest/blob/main/machine%20learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/CardioGoodFitness - CardioGoodFitness (1).csv')

# %%
df.head(5)
# Out:
#   Product  Age  Gender MaritalStatus  FitnessScore  Income  Miles
# 0   TM195   18    Male        Single             4   29562    112
# 1   TM195   19    Male        Single             3   31836     75
# 2   TM195   19  Female     Partnered             3   30699     66
# 3   TM195   19    Male        Single             3   32973     85
# 4   TM195   20    Male     Partnered             2   35247     47

# %%
plt.hist(df['Age'], bins=20, rwidth=0.8)
plt.xlabel('Age (inches)')
plt.ylabel('count')
plt.show()

# %%
df.describe()
# Out:
#               Age  FitnessScore         Income       Miles
# count  180.000000    180.000000     180.000000  180.000000
# mean    28.788889      3.311111   53719.577778  103.194444
# std      6.943498      0.958869   16506.684226   51.863605
# min     18.000000      1.000000   29562.000000   21.000000
# 25%     24.000000      3.000000   44058.750000   66.000000
# 50%     26.000000      3.000000   50596.500000   94.000000
# 75%     33.000000      4.000000   58668.000000  114.750000
# max     50.000000      5.000000  104581.000000  360.000000

# %%
df.Age.mean()
# Out:
# 28.788888888888888

# %%
df.Age.std()
# Out:
# 6.943498135399795

# %%
upper_limit = df.Age.mean() + 3*df.Age.std()
upper_limit
# Out:
# 49.61938329508827

# %%
lower_limit = df.Age.mean() - 3*df.Age.std()
lower_limit
# Out:
# 7.958394482689503

# %%
df[(df.Age>upper_limit) | (df.Age<lower_limit)]
# Out:
#    Product  Age  Gender MaritalStatus  FitnessScore  Income  Miles
# 79   TM195   50  Female     Partnered             3   64809     66

# %%
df_no_outlier_std_dev = df[(df.Age<upper_limit) & (df.Age>lower_limit)]

# %%
df_no_outlier_std_dev.shape
# Out:
# (179, 7)

# %%
df.shape[0] - df_no_outlier_std_dev.shape[0]
# Out:
# 1

# %%
df.info
# Out:
# <bound method DataFrame.info of     Product  Age  Gender MaritalStatus  FitnessScore  Income  Miles
# 0     TM195   18    Male        Single             4   29562    112
# 1     TM195   19    Male        Single             3   31836     75
# 2     TM195   19  Female     Partnered             3   30699     66
# 3     TM195   19    Male        Single             3   32973     85
# 4     TM195   20    Male     Partnered             2   35247     47
# ..      ...  ...     ...           ...           ...     ...    ...
# 175   TM798   40    Male        Single             5   83416    200
# 176   TM798   42    Male        Single             4   89641    200
# 177   TM798   45    Male        Single             5   90886    160
# 178   TM798   47    Male     Partnered             5  104581    120
# 179   TM798   48    Male     Partnered             5   95508    180
#
# [180 rows x 7 columns]>

# %%
data = pd.DataFrame(df)

# %%
data
# Out:
#     Product  Age  Gender MaritalStatus  FitnessScore  Income  Miles
# 0     TM195   18    Male        Single             4   29562    112
# 1     TM195   19    Male        Single             3   31836     75
# 2     TM195   19  Female     Partnered             3   30699     66
# 3     TM195   19    Male        Single             3   32973     85
# 4     TM195   20    Male     Partnered             2   35247     47
# ..      ...  ...     ...           ...           ...     ...    ...
# 175   TM798   40    Male        Single             5   83416    200
# 176   TM798   42    Male        Single             4   89641    200
# 177   TM798   45    Male        Single             5   90886    160
# 178   TM798   47    Male     Partnered             5  104581    120
# 179   TM798   48    Male     Partnered             5   95508    180
#
# [180 rows x 7 columns]

# %%
fig = plt.figure()

# %%
ax = fig.add_axes([0,0,0.5,1.0])
x = list(data.iloc[:0])
y = list(data.iloc[:1])
ax.bar(x,y,color='b')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Define the dataset
data = [10, 5, 80, 30, 20, 9, 2, 150, 70, 11, 155, 90]

# Step 1: Calculate the mean
mean = sum(data) / len(data)

#
squared_diff = [(x - mean) ** 2 for x in data]

variance = sum(squared_diff) / len(data)


std_dev = variance ** 0.5


z_scores = [(x - mean) / std_dev for x in data]

print("Standard Deviation:", std_dev)
print("Z-Scores:", z_scores)
# Out:
# Standard Deviation: 53.440517296232166
# Z-Scores: [-0.7983954651890109, -0.8919574337658481, 0.5114720948867102, -0.42414759088166204, -0.6112715280353365, -0.8171078589043783, -0.9480946149119505, 1.8213396549624314, 0.32434815773303577, -0.7796830714736435, 1.9149016235392686, 0.6985960320403847]

# %%
import numpy as np

data = [10, 5, 80, 30, 20, 9, 2, 150, 70, 11, 155, 90]

# Mean
mean_value = np.mean(data)
print("Mean:", mean_value)

# Standard Deviation
std_dev = np.std(data)
print("Standard Deviation:", std_dev)

# Z-scores
z_scores = (data - mean_value) / std_dev
print("Z-scores:", z_scores)
# Out:
# Mean: 52.666666666666664
# Standard Deviation: 53.440517296232166
# Z-scores: [-0.79839547 -0.89195743  0.51147209 -0.42414759 -0.61127153 -0.81710786
#  -0.94809461  1.82133965  0.32434816 -0.77968307  1.91490162  0.69859603]
